# %%
#ACF and PACF Analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
PD = pd.read_csv("C:/Users/deeks/Downloads/AirPassengers.csv")
PD
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
plt.title('Airline Passengers Dataset', size=20)
plt.plot(PD["Passengers"])

# %%
# First-order difference
PD['Passengers_Diff'] = PD['Passengers'].diff(periods=1)
PD = PD.dropna()
# Plot
plt.title('Airline Passengers dataset with First-order difference', size=20)
plt.plot(PD['Passengers'], label='Passengers')
plt.plot(PD['Passengers_Diff'], label='First-order difference', color='orange')
plt.legend();

# %%
# Calculate autocorrelation
acf_values = acf(PD['Passengers_Diff'])
acf_values
# Out:
# C:\Users\deeks\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:657: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# C:\Users\deeks\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# array([ 1.        ,  0.30285526, -0.10214755, -0.24127349, -0.30040158,
#        -0.09407271, -0.07844257, -0.0923622 , -0.29480158, -0.19177821,
#        -0.10491707,  0.28293105,  0.82917786,  0.28450079, -0.10575172,
#        -0.22213093, -0.23107603, -0.06227904, -0.06618505, -0.09039973,
#        -0.29710958, -0.16273198, -0.08299369,  0.25551054,  0.70108554,
#         0.25701406, -0.09817935, -0.1960499 , -0.1739647 , -0.06923038,
# ...

# %%
# Plot autocorrelation
plot_acf(PD['Passengers_Diff'], lags=30)

# %%
# Calculate partial autocorrelation
pacf_values = pacf(PD['Passengers_Diff'])
pacf_values
# Plot partial autocorrelation
plot_pacf(PD['Passengers_Diff'], lags=30)
# Out:
# C:\Users\deeks\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1024: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs // 2 - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# C:\Users\deeks\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
