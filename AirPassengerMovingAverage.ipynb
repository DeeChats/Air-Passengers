# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
#Importing Dataset
data=pd.read_csv("C:/Users/deeks/Downloads/AirPassengers.csv")
data
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
#3 yearly Moving Average
data['SMA_3']= data['Passengers'].rolling(window=10).mean()
print(data['SMA_3'].tail(30))
# Out:
# 114    364.5
# 115    380.3
# 116    390.2
# 117    392.5
# 118    389.5
# 119    391.4
# 120    391.2
# 121    390.6
# 122    394.9
# 123    391.0
# 124    383.9
# 125    380.6
# 126    395.0
# 127    415.0
# 128    430.3
# 129    437.3
# 130    437.5
# 131    443.8
# 132    444.9
# 133    444.4
# 134    444.3
# 135    443.2
# 136    435.6
# 137    433.2
# 138    449.1
# 139    469.0
# 140    483.6
# 141    489.2
# 142    486.5
# 143    490.6
# Name: SMA_3, dtype: float64

# %%
#line plot
data['Passengers'].plot(color='yellow',linewidth=3,figsize=(12,6))
data['SMA_3'].plot(color='blue',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Air Passengers',fontsize=20)
plt.xlabel('Month',fontsize=16)
plt.ylabel('Passengers',fontsize=16)
# Out:
# Text(0, 0.5, 'Passengers')

# %%
#5 yearly Moving Average
data['SMA_5']= data['Passengers'].rolling(window=10).mean()
print(data['SMA_5'].tail(30))
# Out:
# 114    364.5
# 115    380.3
# 116    390.2
# 117    392.5
# 118    389.5
# 119    391.4
# 120    391.2
# 121    390.6
# 122    394.9
# 123    391.0
# 124    383.9
# 125    380.6
# 126    395.0
# 127    415.0
# 128    430.3
# 129    437.3
# 130    437.5
# 131    443.8
# 132    444.9
# 133    444.4
# 134    444.3
# 135    443.2
# 136    435.6
# 137    433.2
# 138    449.1
# 139    469.0
# 140    483.6
# 141    489.2
# 142    486.5
# 143    490.6
# Name: SMA_5, dtype: float64

# %%
#line plot
data['Passengers'].plot(color='orange',linewidth=3,figsize=(12,6))
data['SMA_5'].plot(color='red',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Air Passengers',fontsize=20)
plt.xlabel('Month',fontsize=16)
plt.ylabel('Passengers',fontsize=16)
# Out:
# Text(0, 0.5, 'Passengers')

# %%
#7 yearly Moving Average
data['SMA_7']= data['Passengers'].rolling(window=10).mean()
print(data['SMA_7'].tail(30))
# Out:
# 114    364.5
# 115    380.3
# 116    390.2
# 117    392.5
# 118    389.5
# 119    391.4
# 120    391.2
# 121    390.6
# 122    394.9
# 123    391.0
# 124    383.9
# 125    380.6
# 126    395.0
# 127    415.0
# 128    430.3
# 129    437.3
# 130    437.5
# 131    443.8
# 132    444.9
# 133    444.4
# 134    444.3
# 135    443.2
# 136    435.6
# 137    433.2
# 138    449.1
# 139    469.0
# 140    483.6
# 141    489.2
# 142    486.5
# 143    490.6
# Name: SMA_7, dtype: float64

# %%
#line plot
data['Passengers'].plot(color='pink',linewidth=3,figsize=(12,6))
data['SMA_7'].plot(color='purple',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Air Passengers',fontsize=20)
plt.xlabel('Month',fontsize=16)
plt.ylabel('Passengers',fontsize=16)
# Out:
# Text(0, 0.5, 'Passengers')

# %%
#10 yearly Moving Average
data['SMA_10']= data['Passengers'].rolling(window=10).mean()
print(data['SMA_10'].tail(30))
# Out:
# 114    364.5
# 115    380.3
# 116    390.2
# 117    392.5
# 118    389.5
# 119    391.4
# 120    391.2
# 121    390.6
# 122    394.9
# 123    391.0
# 124    383.9
# 125    380.6
# 126    395.0
# 127    415.0
# 128    430.3
# 129    437.3
# 130    437.5
# 131    443.8
# 132    444.9
# 133    444.4
# 134    444.3
# 135    443.2
# 136    435.6
# 137    433.2
# 138    449.1
# 139    469.0
# 140    483.6
# 141    489.2
# 142    486.5
# 143    490.6
# Name: SMA_10, dtype: float64

# %%
#line plot
data['Passengers'].plot(color='grey',linewidth=3,figsize=(12,6))
data['SMA_10'].plot(color='green',linewidth=3,figsize=(12,6))
#title and labels
plt.title('The Air Passengers',fontsize=20)
plt.xlabel('Month',fontsize=16)
plt.ylabel('Passengers',fontsize=16)
# Out:
# Text(0, 0.5, 'Passengers')
